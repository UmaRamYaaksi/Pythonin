# %%
from multiFunctions import multipleFunctions
multipleFunctions.subfield()
# Out:
# Subfields in AI are:
# Machine Learning
# Neural Networks
# Computer Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multipleFunctions.oddEven()
# Out:
# Enter the Number for odd/even 67
# 67 is Odd Number

# %%
multipleFunctions.marksCalculation()
# Out:
# Enter the number of subjects 4
# Enter the Marks for each subject out of 100
# Subject1 89
# Subject2 90
# Subject3 97
# Subject4 96
# Total: 372
# Percentage: 93.0

# %%
multipleFunctions.AreaPerimeterOfTriangle()
# Out:
# ##To get Area of Triangle##
# Height: 12
# Breadth: 10
# Area Formula : (Height*Breadth)/2
# Area of triangle: 60.0
#
# ##To get Perimeter of Triangle##
# Height1: 1
# Height2: 2
# Breadth1: 3
# Perimeter Formula : (Height1+Height2+Breadth)
# perimeter of triangle: 6
