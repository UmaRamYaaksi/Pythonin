# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
num1=10
print("Num1=",num1)
num2=30
print("Num2=",num2)
print("Add=",num1+num2)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
BdyMassIn=float(input("Enter the BMI Index"))
if(BdyMassIn<18.5):
    print("Under Weight")
elif(BdyMassIn<25):
    print("Normal")
elif(BdyMassIn<30):
    print("Over Weight")
elif(BdyMassIn<35):
    print("Obese")
else:
    print("Extremely Obese")
# Out:
# Enter the BMI Index 34
# Obese
