# %%
num1=10
num2=30
add=num1+num2
print(add)
print("add")
# Out:
# 40
# add

# %%
print("Addition of two Numbers")
Num1=10
print("The Number 1: ",Num1)
Num2=20
print("The Number 2: ",Num2)
print("The Number 3: ",Num1+Num2)
# Out:
# Addition of two Numbers
# The Number 1:  10
# The Number 2:  20
# The Number 3:  30

# %%
print("Addition of 2 numbers to get input from user")
num1=input("Enter the number1:")
num2=input("Enter the number2:")
add=num1+num2
print(add)
# Out:
# Addition of 2 numbers to get input from user
# Enter the number1: 30
# Enter the number2: 90
# 3090

# %%
print("Addition of 2 numbers to get input from user")
num1=int(input("Enter the number1:"))
num2=int(input("Enter the number2:"))
add=num1+num2
print(add)
# Out:
# Addition of 2 numbers to get input from user
# Enter the number1: 50
# Enter the number2: 80
# 130
