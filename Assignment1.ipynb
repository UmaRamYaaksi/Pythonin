# %%
print("Hope AI")
# Out:
# Hope AI

# %%
InstName=input("Enter your Institute name? : ")
# Out:
# Enter your Institute name? :  Hope AI

# %%
Name=input("Enter your Name:")
Age=int(input("Enter your Age:"))
Schl=input("Enter your School:")
Degree=input("Enter your Degree:")
# Out:
# Enter your Name: Umamaheswari S
# Enter your Age: 30
# Enter your School: VMHSS
# Enter your Degree: B.E ECE

# %%
a=43
b=34
print("a=",a,"\nb=",b,"\nadd=",a+b,"\nSub=",a-b,"\nMul=",a*b,"\nFloat Div=",a/b,"\nFloor Div",int(a/b))
# Out:
# a= 43
# b= 34
# add= 77
# Sub= 9
# Mul= 1462
# Float Div= 1.2647058823529411
# Floor Div 1

# %%
print("Modulo=",a%b)
# Out:
# Modulo= 9

# %%
#Power
a=4
b=4
print("Power=",a**b)
# Out:
# Power= 256
