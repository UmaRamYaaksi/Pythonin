# %%
fieldlst=['Machine Learning','Neural Networks','Computer Vision','Robotics','Speech Processing','Natural Language Processing']
def subfield (fieldlst1):
    print("Subfields in AI are:")
    for temp in fieldlst1:
        print(temp)
subfield(fieldlst)
# Out:
# Subfields in AI are:
# Machine Learning
# Neural Networks
# Computer Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
##Odd od Even number
num=int(input("Enter the Number"))
def oddEven(num12):
    if(num12%2==0):
        print(num12,"is Even Number")
    else:
        print(num12,"is Odd Number")
oddEven(num)
# Out:
# Enter the Number 52452
# 52452 is Even Number

# %%
##Eligibility for marriage 21 for male and 18 for female 
gen=input("Enter your gender")
age=int(input("Enter your age"))
def checkWedElig(gen1,age1):
    if((gen1.casefold()=="male" and age>=21)or (gen1.casefold()=="female" and age>=18)):#casefold converts string into lower case
        print("You are Eligibile for Marriage")
    else:
        print("You are not Eligibile for Marriage")
checkWedElig(gen,age)
# Out:
# Enter your gender Male
# Enter your age 22
# You are Eligibile for Marriage

# %% [markdown]
# ## marks and percentage
# subtotal=0
# NoofSub=int(input("Enter the number of subjects"))
# for temp in range(0,NoofSub):
#     print(f"Subject,{temp+1}")
#     subjectMarks=int(input(""))
#     subtotal+=subjectMarks
# print("Total:",subtotal)
# print("Percentage:",subtotal/NoofSub)

# %%
## marks and percentage
subtotal=0
NoofSub=int(input("Enter the number of subjects"))
print("Enter the Marks for each subject out of 100")
for temp in range(0,NoofSub):
    ##print(f"\rSubject{temp+1}")
   ## subjectMarks=int(input(""))
    subjectMarks=int(input(f"\rSubject{temp+1}"))
    subtotal+=subjectMarks
print("Total:",subtotal)
print("Percentage:",subtotal/NoofSub)
# Out:
# Enter the number of subjects 4
# Enter the Marks for each subject out of 100
# Subject1 78
# Subject2 90
# Subject3 89
# Subject4 90
# Total: 347
# Percentage: 86.75

# %%
##Area and perimeter of triangle
print("##To get Area of Triangle##")
Height=int(input("Height:"))
Breadth=int(input("Breadth:"))
print("Area Formula : (Height*Breadth)/2")
Area = (Height*Breadth)/2
print("Area of triangle:",Area)
print("\n##To get Perimeter of Triangle##")
Height1=int(input("Height1:"))
Height2=int(input("Height2:"))
Breadth1=int(input("Breadth1:"))
print("Perimeter Formula : (Height1+Height2+Breadth)")
perimeter=Height1+Height2+Breadth1
print("perimeter of triangle:",perimeter)
# Out:
# ##To get Area of Triangle##
# Height: 32
# Breadth: 34
# Area Formula : (Height*Breadth)/2
# Area of triangle: 544.0
#
# ##To get Perimeter of Triangle##
